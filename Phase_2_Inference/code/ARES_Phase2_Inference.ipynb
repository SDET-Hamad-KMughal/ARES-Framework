# %% [markdown]
# <a href="https://colab.research.google.com/github/SDET-Hamad-KMughal/ARES-Framework/blob/main/Phase_2_Inference/code/ARES_Phase2_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

# 1. Mount Google Drive (Follow the popup instructions)
drive.mount('/content/drive')

# 2. Path to your specific folder
# Ensure the name matches exactly: 'ARES_test_images'
drive_path = '/content/drive/MyDrive/ARES_test_images'

# 3. Check if folder exists and list all images
if os.path.exists(drive_path):
    images = [f for f in os.listdir(drive_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    print(f"✅ Found {len(images)} images in {drive_path}:")
    for img in images:
        print(f" - {img}")
else:
    print(f"❌ Folder not found! Check if the folder name is correct in your Drive.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Found 5 images in /content/drive/MyDrive/ARES_test_images:
#  - Airbnb iOS 2.png
#  - Messenger iOS 1.png
#  - Skype iOS 20.png
#  - Telegram iOS 20.png
#  - GroupMe iOS 21.png

# %%
from ultralytics import YOLO

# 1. Load your custom model
model = YOLO('best.pt')

# 2. Run detection on your Drive folder
# 'save=True' will create a new folder with the results
results = model.predict(
    source='/content/drive/MyDrive/ARES_test_images',
    conf=0.25,
    save=True
)

print("\n🎯 AI Vision complete!")
print("Check the sidebar: runs/detect/predict (or the highest number)")
# Out:
# image 1/5 /content/drive/MyDrive/ARES_test_images/Airbnb iOS 2.png: 640x288 1 ArrowButton, 1 Checkmark, 1 DropDown, 2 Icons, 1 Input, 5 TextButtons, 225.2ms
# image 2/5 /content/drive/MyDrive/ARES_test_images/GroupMe iOS 21.png: 640x288 1 DropDown, 8 Icons, 90.2ms
# image 3/5 /content/drive/MyDrive/ARES_test_images/Messenger iOS 1.png: 640x288 1 ClickableText, 2 Icons, 4 TextButtons, 89.2ms
# image 4/5 /content/drive/MyDrive/ARES_test_images/Skype iOS 20.png: 640x288 3 Icons, 88.9ms
# image 5/5 /content/drive/MyDrive/ARES_test_images/Telegram iOS 20.png: 640x288 5 Icons, 1 TextButton, 87.4ms
# Speed: 2.8ms preprocess, 116.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 288)
# Results saved to /content/runs/detect/predict2
#
# 🎯 AI Vision complete!
# Check the sidebar: runs/detect/predict (or the highest number)
